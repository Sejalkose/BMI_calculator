# %% [markdown]
# <a href="https://colab.research.google.com/github/Sejalkose/BMI_calculator/blob/main/BMI_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
height = int(input("Enter your height: "))
height1 = height/100
weight = int(input("Enter your weight in kg: "))

BMI =  weight/(height1**2)

if(BMI <18.5):
  print(f"Your BMI is {BMI:.2f}, you are underweight.")
elif(BMI >= 18.5 and BMI < 25):
  print(f"Your BMI is {BMI:.2f}, you have normal weight.")
elif(BMI >= 25 and BMI < 30):
  print(f"Your BMI is {BMI:.2f}, you are slightly overweight.")
elif(BMI >= 30 and BMI < 35):
  print(f"Your BMI is {BMI:.2f}, you are obese.")
else:
  print(f"Your BMI is {BMI:.2f}, you are normal weight.")
# Out:
# Enter your height: 155
# Enter your weight in kg: 45
# Your BMI is 18.73, you have normal weight.
